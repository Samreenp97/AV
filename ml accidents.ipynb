# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Road_Accidents.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-f291301f051c> in <module>
# ----> 1 data = pd.read_csv('Road_Accidents.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# ...

# %%
data.shape
# Out:
# (27, 16)

# %%
data
# Out:
#     Years  Total Number of Road Accidents (in numbers)  \
# 0    1970                                       114100
# 1    1980                                       153200
# 2    1990                                       282600
# 3    1994                                       325864
# 4    1995                                       351999
# 5    1996                                       371204
# 6    1997                                       373671
# 7    1998                                       385018
# 8    1999                                       386456
# 9    2000                                       391449
# 10   2001                                       405637
# 11   2002                                       407497
# 12   2003                                       406726
# 13   2004                                       429910
# 14   2005                                       439255
# 15   2006                                       460920
# ...

# %%
data.dtypes
# Out:
# Years                                                         int64
# Total Number of Road Accidents (in numbers)                   int64
# Total Number of Persons Killed (in numbers)                   int64
# Total Number of Persons Injured (in numbers)                  int64
# Population of India (in thousands)                          float64
# Total Number of Registered Motor Vehicles (in thousands)    float64
# Road Length (in kms)                                        float64
# Number of Accidents per Lakh Population                     float64
# Number of Accidents per Ten Thousand Vehicles               float64
# Number of Accidents per Ten Thousand Kms of Roads           float64
# Number of Persons Killed Per Lakh Population                float64
# Number of Persons Killed Per Ten Thousand Vehicles          float64
# Number of Persons Killed per Ten Thousand Kms of Roads      float64
# Number of Persons Injured per Lakh Population               float64
# ...

# %%
# Print the total number of road accidents from 1970 to 2000

data.iloc[:,1].loc[(data['Years']>=1970) & (data['Years']<=2000)].sum()
# Out:
# 3135561

# %%
# Print the total number of persons killed where number of road accidents is greater than 400000

data.iloc[:,2].loc[(data['Total Number of Road Accidents (in numbers)'] > 400000)].sum()
# Out:
# 2042189

# %%
#Print the percent of people killed in road accidents in the year 2006

data.iloc[:,2].loc[(data['Years']==2006)].sum()
# Out:
# 105749

# %%
total_number_in_2006 = 105749
total_number_in_pop = 1112186

percent_of_people_killed= (total_number_in_2006/total_number_in_pop) * 100 

percent_of_people_killed
# Out:
# 9.508211755947297

# %%
data.isnull().sum()
# Out:
# Years                                                       0
# Total Number of Road Accidents (in numbers)                 0
# Total Number of Persons Killed (in numbers)                 0
# Total Number of Persons Injured (in numbers)                0
# Population of India (in thousands)                          0
# Total Number of Registered Motor Vehicles (in thousands)    1
# Road Length (in kms)                                        1
# Number of Accidents per Lakh Population                     0
# Number of Accidents per Ten Thousand Vehicles               1
# Number of Accidents per Ten Thousand Kms of Roads           1
# Number of Persons Killed Per Lakh Population                0
# Number of Persons Killed Per Ten Thousand Vehicles          1
# Number of Persons Killed per Ten Thousand Kms of Roads      1
# Number of Persons Injured per Lakh Population               0
# Number of Persons Injured Per Ten Thousand Vehicles         1
# ...

# %%
data.iloc[26]
# Out:
# Years                                                          2017.0
# Total Number of Road Accidents (in numbers)                  464910.0
# Total Number of Persons Killed (in numbers)                  147913.0
# Total Number of Persons Injured (in numbers)                 470975.0
# Population of India (in thousands)                          1283601.0
# Total Number of Registered Motor Vehicles (in thousands)          NaN
# Road Length (in kms)                                              NaN
# Number of Accidents per Lakh Population                          36.2
# Number of Accidents per Ten Thousand Vehicles                     NaN
# Number of Accidents per Ten Thousand Kms of Roads                 NaN
# Number of Persons Killed Per Lakh Population                     11.5
# Number of Persons Killed Per Ten Thousand Vehicles                NaN
# Number of Persons Killed per Ten Thousand Kms of Roads            NaN
# ...

# %%
m1 = data['Total Number of Registered Motor Vehicles (in thousands)'].median()
data['Total Number of Registered Motor Vehicles (in thousands)'].fillna(m1, inplace = True)

# %%
m2 = data['Road Length (in kms)'].median()
data['Road Length (in kms)'].fillna(m2,inplace = True)

# %%
m3= data['Number of Accidents per Ten Thousand Vehicles'].median()
data['Number of Accidents per Ten Thousand Vehicles'].fillna(m3,inplace = True)

# %%
m4= data['Number of Accidents per Ten Thousand Kms of Roads'].median()

data['Number of Accidents per Ten Thousand Kms of Roads'].fillna(m4,inplace = True)

# %%
m5= data['Number of Persons Killed Per Ten Thousand Vehicles'].median()
data['Number of Persons Killed Per Ten Thousand Vehicles'].fillna(m5,inplace = True )

# %%
m6= data['Number of Persons Killed per Ten Thousand Kms of Roads'].median()
data['Number of Persons Killed per Ten Thousand Kms of Roads'].fillna(m6,inplace = True)

# %%
m7= data['Number of Persons Injured Per Ten Thousand Vehicles'].median()
data['Number of Persons Injured Per Ten Thousand Vehicles'].fillna(m7,inplace = True)

# %%
m8= data['Number of Persons Injured Per Ten Thousand Kms of Roads'].median()
data['Number of Persons Injured Per Ten Thousand Kms of Roads'].fillna(m8,inplace = True)

# %%
data.isnull().sum()
# Out:
# Years                                                       0
# Total Number of Road Accidents (in numbers)                 0
# Total Number of Persons Killed (in numbers)                 0
# Total Number of Persons Injured (in numbers)                0
# Population of India (in thousands)                          0
# Total Number of Registered Motor Vehicles (in thousands)    0
# Road Length (in kms)                                        0
# Number of Accidents per Lakh Population                     0
# Number of Accidents per Ten Thousand Vehicles               0
# Number of Accidents per Ten Thousand Kms of Roads           0
# Number of Persons Killed Per Lakh Population                0
# Number of Persons Killed Per Ten Thousand Vehicles          0
# Number of Persons Killed per Ten Thousand Kms of Roads      0
# Number of Persons Injured per Lakh Population               0
# Number of Persons Injured Per Ten Thousand Vehicles         0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data.shape
# Out:
# (27, 16)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 16 columns):
# Years                                                       27 non-null int64
# Total Number of Road Accidents (in numbers)                 27 non-null int64
# Total Number of Persons Killed (in numbers)                 27 non-null int64
# Total Number of Persons Injured (in numbers)                27 non-null int64
# Population of India (in thousands)                          27 non-null float64
# Total Number of Registered Motor Vehicles (in thousands)    27 non-null float64
# Road Length (in kms)                                        27 non-null float64
# Number of Accidents per Lakh Population                     27 non-null float64
# Number of Accidents per Ten Thousand Vehicles               27 non-null float64
# Number of Accidents per Ten Thousand Kms of Roads           27 non-null float64
# ...

# %%
data.describe()
# Out:
#              Years  Total Number of Road Accidents (in numbers)  \
# count    27.000000                                    27.000000
# mean   2002.666667                                409124.740741
# std      10.891069                                 99090.505944
# min    1970.000000                                114100.000000
# 25%    1997.500000                                379344.500000
# 50%    2004.000000                                429910.000000
# 75%    2010.500000                                485544.000000
# max    2017.000000                                501423.000000
#
#        Total Number of Persons Killed (in numbers)  \
# count                                    27.000000
# mean                                  98610.037037
# std                                   37324.713290
# min                                   14500.000000
# 25%                                   77944.000000
# 50%                                   92618.000000
# ...

# %%
data
# Out:
#     Years  Total Number of Road Accidents (in numbers)  \
# 0    1970                                       114100
# 1    1980                                       153200
# 2    1990                                       282600
# 3    1994                                       325864
# 4    1995                                       351999
# 5    1996                                       371204
# 6    1997                                       373671
# 7    1998                                       385018
# 8    1999                                       386456
# 9    2000                                       391449
# 10   2001                                       405637
# 11   2002                                       407497
# 12   2003                                       406726
# 13   2004                                       429910
# 14   2005                                       439255
# 15   2006                                       460920
# ...

# %%
X = data.drop('Total Number of Persons Killed (in numbers)',axis = 1)
Y = data['Total Number of Persons Killed (in numbers)']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
Y_pred=regressor.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

mse=round((mean_squared_error(Y_test,Y_pred))/100, 2)
rmse = round((sqrt(mse))/100 ,2)
mse ,rmse


## In order to reduce my MSE value I want to go for feature selection by Backward Elimination.
# Out:
# (2155.76, 0.46)

# %%
import statsmodels.api as sm
X=sm.add_constant(X)
model=sm.OLS(Y,X).fit()
model.summary()
# Out:
# /anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                          OLS Regression Results
# ...
# Dep. Variable:     Total Number of Persons Killed (in numbers)   R-squared:                       1.000
# Model:                                                     OLS   Adj. R-squared:                  1.000
# Method:                                          Least Squares   F-statistic:                 3.267e+04
# Date:                                         Sat, 12 Oct 2019   Prob (F-statistic):           2.40e-23
# Time:                                                 12:15:31   Log-Likelihood:                -177.53
# No. Observations:                                           27   AIC:                             387.1
# ...

# %%
X=X.drop(['Years','Number of Persons Injured Per Ten Thousand Kms of Roads'],axis=1)
model=sm.OLS(Y,X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                          OLS Regression Results
# ...
# Dep. Variable:     Total Number of Persons Killed (in numbers)   R-squared:                       1.000
# Model:                                                     OLS   Adj. R-squared:                  1.000
# Method:                                          Least Squares   F-statistic:                 2.463e+04
# Date:                                         Sat, 12 Oct 2019   Prob (F-statistic):           2.53e-26
# Time:                                                 12:30:19   Log-Likelihood:                -185.53
# No. Observations:                                           27   AIC:                             399.1
# Df Residuals:                                               13   BIC:                             417.2
# Df Model:                                                   13
# Covariance Type:                                     nonrobust
# ...

# %%
X=X.drop(['Number of Accidents per Ten Thousand Kms of Roads','Number of Accidents per Ten Thousand Vehicles','Number of Accidents per Lakh Population','Road Length (in kms)','Total Number of Registered Motor Vehicles (in thousands)','Total Number of Persons Injured (in numbers)','Total Number of Road Accidents (in numbers)'],axis=1)
model=sm.OLS(Y,X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                          OLS Regression Results
# ...
# Dep. Variable:     Total Number of Persons Killed (in numbers)   R-squared:                       0.999
# Model:                                                     OLS   Adj. R-squared:                  0.999
# Method:                                          Least Squares   F-statistic:                     5708.
# Date:                                         Sat, 12 Oct 2019   Prob (F-statistic):           3.02e-31
# Time:                                                 12:33:32   Log-Likelihood:                -221.52
# No. Observations:                                           27   AIC:                             457.0
# Df Residuals:                                               20   BIC:                             466.1
# Df Model:                                                    6
# Covariance Type:                                     nonrobust
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
Y_pred=regressor.predict(X_test)

# %%
mse=round((mean_squared_error(Y_test,Y_pred))/100, 2)
rmse = round((sqrt(mse))/100 ,2)
mse ,rmse
# Out:
# (8456.15, 0.92)
